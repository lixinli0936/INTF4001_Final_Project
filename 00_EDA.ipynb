# %%
# !pip3 install openpyxl

# %%
import pandas as pd

# %%
dict=pd.read_excel('./data/dft-road-casualty-statistics-road-safety-open-dataset-data-guide-2023.xlsx')
dict.head()
# Out:
#       table           field name code/format label  \
# 0  Accident      collision_index         NaN   NaN
# 1  Accident       collision_year         NaN   NaN
# 2  Accident  collision_reference         NaN   NaN
# 3  Accident       accident_index         NaN   NaN
# 4  Accident        accident_year         NaN   NaN
#
#                                                 note
# 0  unique value for each accident. The accident_i...
# 1                                                NaN
# 2  In year id used by the police to reference a c...
# 3  unique value for each accident. The accident_i...
# 4                                                NaN

# %%
dict[dict['table']=='Accident']
# Out:
#          table                  field name code/format  \
# 0     Accident             collision_index         NaN
# 1     Accident              collision_year         NaN
# 2     Accident         collision_reference         NaN
# 3     Accident              accident_index         NaN
# 4     Accident               accident_year         NaN
# ...        ...                         ...         ...
# 1371  Accident             trunk_road_flag           1
# 1372  Accident             trunk_road_flag           2
# 1373  Accident             trunk_road_flag          -1
# 1374  Accident  lsoa_of_collision_location         NaN
# 1375  Accident   lsoa_of_accident_location         NaN
#
#                                           label  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...

# %%
dict['table'].drop_duplicates()
# Out:
# 0                   Accident
# 1376                 Vehicle
# 1605               e_scooter
# 1614                Casualty
# 1733    historical_revisions
# 1743    collision_adjustment
# 1754     casualty_adjustment
# Name: table, dtype: object

# %%
accidents=pd.read_csv('./data/Accident/dft-road-casualty-statistics-collision-2018.csv',low_memory=False)
accidents.head(10)
# Out:
#   accident_index  accident_year accident_reference  location_easting_osgr  \
# 0  2018010080971           2018          010080971               529150.0
# 1  2018010080973           2018          010080973               542020.0
# 2  2018010080974           2018          010080974               531720.0
# 3  2018010080981           2018          010080981               541450.0
# 4  2018010080982           2018          010080982               543580.0
# 5  2018010080983           2018          010080983               526060.0
# 6  2018010080986           2018          010080986               525050.0
# 7  2018010080987           2018          010080987               536710.0
# 8  2018010080990           2018          010080990               517110.0
# 9  2018010080992           2018          010080992               535450.0
#
#    location_northing_osgr  longitude   latitude  police_force  \
# 0                182270.0  -0.139737  51.524587             1
# ...

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122635 entries, 0 to 122634
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_index                               122635 non-null  object
#  1   accident_year                                122635 non-null  int64
#  2   accident_reference                           122635 non-null  object
#  3   location_easting_osgr                        122580 non-null  float64
#  4   location_northing_osgr                       122580 non-null  float64
#  5   longitude                                    122580 non-null  float64
#  6   latitude                                     122580 non-null  float64
#  7   police_force                                 122635 non-null  int64
#  8   accident_severity                            122635 non-null  int64
# ...

# %%
# choose the fields of fact table
facts={}
facts['Accident']=['accident_index','accident_year','longitude','latitude','accident_severity','number_of_vehicles','number_of_casualties','date','time','road_type','weather_conditions']

# fact table name and the referenced dimention table name
dimentions={}
dimentions['Accident']=['accident_severity','road_type','weather_conditions']

# %%
accidents[facts['Accident']].dtypes
# Out:
# accident_index           object
# accident_year             int64
# longitude               float64
# latitude                float64
# accident_severity         int64
# number_of_vehicles        int64
# number_of_casualties      int64
# date                     object
# time                     object
# road_type                 int64
# weather_conditions        int64
# dtype: object

# %%
casualties=pd.read_csv('./data/Casualty/dft-road-casualty-statistics-casualty-2018.csv',low_memory=False)
casualties.head(10)
# Out:
#   accident_index  accident_year accident_reference  vehicle_reference  \
# 0  2018010080971           2018          010080971                  1
# 1  2018010080971           2018          010080971                  2
# 2  2018010080973           2018          010080973                  1
# 3  2018010080974           2018          010080974                  1
# 4  2018010080981           2018          010080981                  1
# 5  2018010080982           2018          010080982                  1
# 6  2018010080982           2018          010080982                  2
# 7  2018010080983           2018          010080983                  1
# 8  2018010080983           2018          010080983                  1
# 9  2018010080983           2018          010080983                  1
#
#    casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                   1               2                2               50
# ...

# %%
casualties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160597 entries, 0 to 160596
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   accident_index                      160597 non-null  object
#  1   accident_year                       160597 non-null  int64
#  2   accident_reference                  160597 non-null  object
#  3   vehicle_reference                   160597 non-null  int64
#  4   casualty_reference                  160597 non-null  int64
#  5   casualty_class                      160597 non-null  int64
#  6   sex_of_casualty                     160597 non-null  int64
#  7   age_of_casualty                     160597 non-null  int64
#  8   age_band_of_casualty                160597 non-null  int64
#  9   casualty_severity                   160597 non-null  int64
#  10  pedestrian_location                 160597 non-null  int64
# ...

# %%
facts['Casualty']=['accident_index','accident_year','vehicle_reference','casualty_reference','casualty_class','sex_of_casualty','age_of_casualty','age_band_of_casualty','casualty_severity']
dimentions['Casualty']=['casualty_class','sex_of_casualty','age_band_of_casualty','casualty_severity']

# %%
casualties[facts['Casualty']].dtypes
# Out:
# accident_index          object
# accident_year            int64
# vehicle_reference        int64
# casualty_reference       int64
# casualty_class           int64
# sex_of_casualty          int64
# age_of_casualty          int64
# age_band_of_casualty     int64
# casualty_severity        int64
# dtype: object

# %%
vehicles=pd.read_csv('./data/Vehicle/dft-road-casualty-statistics-vehicle-2018.csv',low_memory=False)
vehicles.head(10)
# Out:
#   accident_index  accident_year accident_reference  vehicle_reference  \
# 0  2018010080971           2018          010080971                  1
# 1  2018010080971           2018          010080971                  2
# 2  2018010080973           2018          010080973                  1
# 3  2018010080974           2018          010080974                  1
# 4  2018010080974           2018          010080974                  2
# 5  2018010080981           2018          010080981                  1
# 6  2018010080981           2018          010080981                  2
# 7  2018010080982           2018          010080982                  1
# 8  2018010080982           2018          010080982                  2
# 9  2018010080983           2018          010080983                  1
#
#    vehicle_type  towing_and_articulation  vehicle_manoeuvre  \
# 0             9                        0                 18
# 1             8                        0                 18
# ...

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226409 entries, 0 to 226408
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   accident_index                    226409 non-null  object
#  1   accident_year                     226409 non-null  int64
#  2   accident_reference                226409 non-null  object
#  3   vehicle_reference                 226409 non-null  int64
#  4   vehicle_type                      226409 non-null  int64
#  5   towing_and_articulation           226409 non-null  int64
#  6   vehicle_manoeuvre                 226409 non-null  int64
#  7   vehicle_direction_from            226409 non-null  int64
#  8   vehicle_direction_to              226409 non-null  int64
#  9   vehicle_location_restricted_lane  226409 non-null  int64
#  10  junction_location                 226409 non-null  int64
# ...

# %%
facts['Vehicle']=['accident_index','accident_year','vehicle_reference','vehicle_type','sex_of_driver','age_of_driver','age_band_of_driver','age_of_vehicle']
dimentions['Vehicle']=['vehicle_type','sex_of_driver','age_band_of_driver']

# %%
vehicles[facts['Vehicle']].dtypes
# Out:
# accident_index        object
# accident_year          int64
# vehicle_reference      int64
# vehicle_type           int64
# sex_of_driver          int64
# age_of_driver          int64
# age_band_of_driver     int64
# age_of_vehicle         int64
# dtype: object

# %%
facts,dimentions
# Out:
# ({'Accident': ['accident_index',
#    'accident_year',
#    'longitude',
#    'latitude',
#    'accident_severity',
#    'number_of_vehicles',
#    'number_of_casualties',
#    'date',
#    'time',
#    'road_type',
#    'weather_conditions'],
#   'Casualty': ['accident_index',
#    'accident_year',
#    'vehicle_reference',
#    'casualty_reference',
#    'casualty_class',
#    'sex_of_casualty',
#    'age_of_casualty',
#    'age_band_of_casualty',
#    'casualty_severity'],
#   'Vehicle': ['accident_index',
#    'accident_year',
#    'vehicle_reference',
#    'vehicle_type',
#    'sex_of_driver',
#    'age_of_driver',
#    'age_band_of_driver',
#    'age_of_vehicle']},
#  {'Accident': ['accident_severity', 'road_type', 'weather_conditions'],
#   'Casualty': ['casualty_class',
#    'sex_of_casualty',
#    'age_band_of_casualty',
#    'casualty_severity'],
#   'Vehicle': ['vehicle_type', 'sex_of_driver', 'age_band_of_driver']})

# %%
field_list = [value for sublist in dimentions.values() for value in sublist]
df=dict.loc[dict['table'].isin(dimentions.keys()) & dict['field name'].isin(field_list)]
df
# Out:
#          table            field name code/format  \
# 65    Accident     accident_severity           1
# 66    Accident     accident_severity           2
# 67    Accident     accident_severity           3
# 1260  Accident             road_type           1
# 1261  Accident             road_type           2
# ...        ...                   ...         ...
# 1641  Casualty  age_band_of_casualty          11
# 1642  Casualty  age_band_of_casualty          -1
# 1643  Casualty     casualty_severity           1
# 1644  Casualty     casualty_severity           2
# 1645  Casualty     casualty_severity           3
#
#                              label note
# 65                           Fatal  NaN
# 66                         Serious  NaN
# 67                          Slight  NaN
# 1260                    Roundabout  NaN
# 1261                One way street  NaN
# ...                            ...  ...
# 1641                       Over 75  NaN
# 1642  Data missing or out of range  NaN
# ...

# %%
df.groupby('field name')['label'].apply(lambda x: x.str.len().max())
# Out:
# field name
# accident_severity        7
# age_band_of_casualty    28
# age_band_of_driver      28
# casualty_class          15
# casualty_severity        7
# road_type               28
# sex_of_casualty         28
# sex_of_driver           28
# vehicle_type            46
# weather_conditions      28
# Name: label, dtype: int64

# %%
df[['field name','code/format']].value_counts().sort_values(ascending=False)
# Out:
# field name            code/format
# accident_severity      1             1
#                        2             1
#                        3             1
# age_band_of_casualty  -1             1
#                        1             1
#                                     ..
# weather_conditions     5             1
#                        6             1
#                        7             1
#                        8             1
#                        9             1
# Name: count, Length: 89, dtype: int64

# %%
gc=df.groupby(['field name','code/format']).count()
gc[gc['label']>1]
# Out:
# Empty DataFrame
# Columns: [table, label, note]
# Index: []
